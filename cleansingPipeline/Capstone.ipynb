# %%
import pandas as pd

# %%
pd.reset_option('display.max_rows')

# %%
#pd.set_option('display.max_rows', None)

# %%
df = pd.read_excel('cosing_clean.xlsx')
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df.shape
# Out:
# (3617, 18)

# %% [markdown]
# 18 Columns, 3617 rows

# %%
df.isna().sum()
# Out:
# Functionality          0
# Canonical_smiles       0
# Chemical Name          0
# Smiles                 0
# Functionality.1        0
# Functionality 0        0
# Functionality 1     1894
# Functionality 2     2911
# Functionality 3     3353
# Functionality 4     3518
# Functionality 5     3579
# Functionality 6     3609
# Functionality 7     3616
# Functionality 8     3617
# Functionality 9     3617
# Functionality 10    3617
# Functionality 11    3617
# Functionality 12    3617
# dtype: int64

# %% [markdown]
# Functionality 8 to Functionality 12 consists of only null values, hence dropping them

# %%
df.drop(['Functionality 8','Functionality 9','Functionality 10','Functionality 11','Functionality 12'], inplace=True, axis=1)

# %%
df.head()
# Out:
#                            Functionality  \
# 0                    emulsionstabilising
# 1                   viscositycontrolling
# 2                       nailconditioning
# 3                   antistatic,humectant
# 4  antistatic,emollient,hairconditioning
#
#                             Canonical_smiles  \
# 0  CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1
# 1      CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1
# 2                                       CC=O
# 3                                 CC(=O)NCCO
# 4            CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
#
#                              Chemical Name  \
# 0                             ABIETIC ACID
# 1                          ABIETYL ALCOHOL
# 2                             ACETALDEHYDE
# 3                            ACETAMIDE MEA
# 4  ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
#
#                                       Smiles  \
# 0  CC(C)C1=CC2=CCC3C(C2CC1)(CCCC3(C)C(=O)O)C
# 1      CC(C)C1=CC2=CCC3C(CCCC3(C2CC1)C)(C)CO
# ...

# %%
df[['Functionality','Functionality.1']]
# Out:
#                                 Functionality  \
# 0                         emulsionstabilising
# 1                        viscositycontrolling
# 2                            nailconditioning
# 3                        antistatic,humectant
# 4       antistatic,emollient,hairconditioning
# ...                                       ...
# 3612             surfactant,foaming,cleansing
# 3613             surfactant,foaming,cleansing
# 3614             surfactant,cleansing,foaming
# 3615  antistatic,surfactant,foaming,cleansing
# 3616                                chelating
#
#                               Functionality.1
# 0                        Emulsion stabilising
# 1                       Viscosity controlling
# 2                           Nail conditioning
# 3                        Antistatic/humectant
# 4      Antistatic/emollient/hair conditioning
# ...                                       ...
# 3612             Surfactant/foaming/cleansing
# ...

# %% [markdown]
# Functionality.1 is cleaned version of Functionalisty, so we can drop Functionality

# %%
df.drop('Functionality', axis=1, inplace=True)

# %%
df.head()
# Out:
#                             Canonical_smiles  \
# 0  CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1
# 1      CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1
# 2                                       CC=O
# 3                                 CC(=O)NCCO
# 4            CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
#
#                              Chemical Name  \
# 0                             ABIETIC ACID
# 1                          ABIETYL ALCOHOL
# 2                             ACETALDEHYDE
# 3                            ACETAMIDE MEA
# 4  ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
#
#                                       Smiles  \
# 0  CC(C)C1=CC2=CCC3C(C2CC1)(CCCC3(C)C(=O)O)C
# 1      CC(C)C1=CC2=CCC3C(CCCC3(C2CC1)C)(C)CO
# 2                                       CC=O
# 3                                 CC(=O)NCCO
# 4            CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
#
#                           Functionality.1        Functionality 0  \
# 0                    Emulsion stabilising   Emulsion stabilising
# ...

# %%
print(df.nunique(axis=0))
# Out:
# Canonical_smiles    2962
# Chemical Name       3256
# Smiles              2962
# Functionality.1      689
# Functionality 0       96
# Functionality 1       62
# Functionality 2       50
# Functionality 3       37
# Functionality 4       26
# Functionality 5       15
# Functionality 6        6
# Functionality 7        1
# dtype: int64

# %%
df[['Canonical_smiles','Smiles']]
# Out:
#                                Canonical_smiles  \
# 0     CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1
# 1         CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1
# 2                                          CC=O
# 3                                    CC(=O)NCCO
# 4               CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
# ...                                         ...
# 3612               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3613               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3614               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3615              CCCCCCCCCCCC(=O)N(C)CC(=O)O.N
# 3616                  O=C(O)CCN(CC(=O)O)CC(=O)O
#
#                                          Smiles
# 0     CC(C)C1=CC2=CCC3C(C2CC1)(CCCC3(C)C(=O)O)C
# 1         CC(C)C1=CC2=CCC3C(CCCC3(C2CC1)C)(C)CO
# 2                                          CC=O
# 3                                    CC(=O)NCCO
# 4               CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
# ...                                         ...
# ...

# %% [markdown]
# Should we keep SMiles and Canonical_Smailes both?

# %%
df['Chemical Name']
# Out:
# 0                                  ABIETIC ACID
# 1                               ABIETYL ALCOHOL
# 2                                  ACETALDEHYDE
# 3                                 ACETAMIDE MEA
# 4       ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
#                          ...
# 3612                 AMMONIUM LAURETH-7 SULFATE
# 3613                 AMMONIUM LAURETH-9 SULFATE
# 3614                AMMONIUM LAURETH-12 SULFATE
# 3615               AMMONIUM LAUROYL SARCOSINATE
# 3616                 BETA-ALANINE DIACETIC ACID
# Name: Chemical Name, Length: 3617, dtype: object

# %%
df[df.duplicated(keep='first')]
# Out:
#                                        Canonical_smiles      Chemical Name  \
# 70    OCC1OC(OC2C3COC2C(O)C(OC2C(O)C(CO)OC(OC4C5COC4...            AGAROSE
# 72                                          CC(N)C(=O)O            ALANINE
# 73                                          CC(N)C(=O)O            ALANINE
# 79                         O=C(O)CCCCCCCC(O)C(O)CCCCCCO     ALEURITIC ACID
# 80                         O=C(O)CCCCCCCC(O)C(O)CCCCCCO     ALEURITIC ACID
# ...                                                 ...                ...
# 3535                        NC(Cc1c[nH]c2ccccc12)C(=O)O         TRYPTOPHAN
# 3538  COC1=C(OC)C(=O)C(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(...         UBIQUINONE
# 3559    Cc1cc(Cl)cc2c1C(=O)C(=C1Sc3cc(Cl)cc(C)c3C1=O)S2          VAT RED 1
# 3588     [O-][n+]1ccccc1[S-].[O-][n+]1ccccc1[S-].[Zn+2]    ZINC PYRITHIONE
# 3598           C=CCCCCCCCCC(=O)O.C=CCCCCCCCCC(=O)O.[Zn]  ZINC UNDECYLENATE
#
#                                                  Smiles  \
# ...

# %% [markdown]
# 241 rows are duplicated, so we'll drop them

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [Canonical_smiles, Chemical Name, Smiles, Functionality.1, Functionality 0, Functionality 1, Functionality 2, Functionality 3, Functionality 4, Functionality 5, Functionality 6, Functionality 7]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3376 entries, 0 to 3616
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Canonical_smiles  3376 non-null   object
#  1   Chemical Name     3376 non-null   object
#  2   Smiles            3376 non-null   object
#  3   Functionality.1   3376 non-null   object
#  4   Functionality 0   3376 non-null   object
#  5   Functionality 1   1609 non-null   object
#  6   Functionality 2   679 non-null    object
#  7   Functionality 3   261 non-null    object
#  8   Functionality 4   99 non-null     object
#  9   Functionality 5   38 non-null     object
#  10  Functionality 6   8 non-null      object
#  11  Functionality 7   1 non-null      object
# dtypes: object(12)
# memory usage: 342.9+ KB

# %%
df.head(2)
# Out:
#                             Canonical_smiles    Chemical Name  \
# 0  CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1     ABIETIC ACID
# 1      CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1  ABIETYL ALCOHOL
#
#                                       Smiles        Functionality.1  \
# 0  CC(C)C1=CC2=CCC3C(C2CC1)(CCCC3(C)C(=O)O)C   Emulsion stabilising
# 1      CC(C)C1=CC2=CCC3C(CCCC3(C2CC1)C)(C)CO  Viscosity controlling
#
#          Functionality 0 Functionality 1 Functionality 2 Functionality 3  \
# 0   Emulsion stabilising             NaN             NaN             NaN
# 1  Viscosity controlling             NaN             NaN             NaN
#
#   Functionality 4 Functionality 5 Functionality 6 Functionality 7
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN

# %%
df['Chemical Name']
# Out:
# 0                                  ABIETIC ACID
# 1                               ABIETYL ALCOHOL
# 2                                  ACETALDEHYDE
# 3                                 ACETAMIDE MEA
# 4       ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
#                          ...
# 3612                 AMMONIUM LAURETH-7 SULFATE
# 3613                 AMMONIUM LAURETH-9 SULFATE
# 3614                AMMONIUM LAURETH-12 SULFATE
# 3615               AMMONIUM LAUROYL SARCOSINATE
# 3616                 BETA-ALANINE DIACETIC ACID
# Name: Chemical Name, Length: 3376, dtype: object

# %%
#df['Chemical Name'].to_frame(name='column_name').to_excel('Ingred.xlsx', sheet_name='Step-1')

# %% [markdown]
# Further Cleaning required!

# %%
df.drop('Smiles',axis=1, inplace=True)

# %%
df.shape
# Out:
# (3376, 11)

# %%
df
# Out:
#                                Canonical_smiles  \
# 0     CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1
# 1         CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1
# 2                                          CC=O
# 3                                    CC(=O)NCCO
# 4               CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
# ...                                         ...
# 3612               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3613               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3614               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3615              CCCCCCCCCCCC(=O)N(C)CC(=O)O.N
# 3616                  O=C(O)CCN(CC(=O)O)CC(=O)O
#
#                                 Chemical Name  \
# 0                                ABIETIC ACID
# 1                             ABIETYL ALCOHOL
# 2                                ACETALDEHYDE
# 3                               ACETAMIDE MEA
# 4     ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
# ...                                       ...
# 3612               AMMONIUM LAURETH-7 SULFATE
# ...

# %%
df.head()
# Out:
#                             Canonical_smiles  \
# 0  CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1
# 1      CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1
# 2                                       CC=O
# 3                                 CC(=O)NCCO
# 4            CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
#
#                              Chemical Name  \
# 0                             ABIETIC ACID
# 1                          ABIETYL ALCOHOL
# 2                             ACETALDEHYDE
# 3                            ACETAMIDE MEA
# 4  ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
#
#                           Functionality.1        Functionality 0  \
# 0                    Emulsion stabilising   Emulsion stabilising
# 1                   Viscosity controlling  Viscosity controlling
# 2                       Nail conditioning      Nail conditioning
# 3                    Antistatic/humectant             Antistatic
# 4  Antistatic/emollient/hair conditioning             Antistatic
#
# ...

# %%
chem_name=df[['Canonical_smiles','Chemical Name']]
chem_name
# Out:
#                                Canonical_smiles  \
# 0     CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1
# 1         CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1
# 2                                          CC=O
# 3                                    CC(=O)NCCO
# 4               CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
# ...                                         ...
# 3612               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3613               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3614               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3615              CCCCCCCCCCCC(=O)N(C)CC(=O)O.N
# 3616                  O=C(O)CCN(CC(=O)O)CC(=O)O
#
#                                 Chemical Name
# 0                                ABIETIC ACID
# 1                             ABIETYL ALCOHOL
# 2                                ACETALDEHYDE
# 3                               ACETAMIDE MEA
# 4     ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
# ...                                       ...
# 3612               AMMONIUM LAURETH-7 SULFATE
# ...

# %%
df[['Canonical_smiles','Chemical Name']][df['Chemical Name'].duplicated(keep='first')]
# Out:
#                                        Canonical_smiles      Chemical Name
# 24    CCN(CC)c1ccc(C(=C2C=CC(=[N+](CC)CC)C=C2)c2cc([...        ACID BLUE 3
# 25    CCN(CC)c1ccc(C(=C2C=CC(=[N+](CC)CC)C=C2)c2cc(O...        ACID BLUE 3
# 27    CCN(Cc1cccc(S(=O)(=O)[O-])c1)c1ccc(C(=C2C=CC(=...        ACID BLUE 9
# 28    CCN(Cc1cccc(S(=O)(=O)O)c1)c1ccc(C(=C2C=CC(=[N+...        ACID BLUE 9
# 29    CCN(Cc1cccc(S(=O)(=O)[O-])c1)c1ccc(C(=C2C=CC(=...        ACID BLUE 9
# ...                                                 ...                ...
# 3587                                   On1ccccc1=S.[Zn]    ZINC PYRITHIONE
# 3589               On1ccccc1=S.[O-][n+]1ccccc1[S-].[Zn]    ZINC PYRITHIONE
# 3595           C=CCCCCCCCCC(=O)O.C=CCCCCCCCCC(=O)O.[Zn]  ZINC UNDECYLENATE
# 3596                           C=CCCCCCCCCC(=O)O.[Zn+2]  ZINC UNDECYLENATE
# 3597                               C=CCCCCCCCCC(=O)[O-]  ZINC UNDECYLENATE
#
# [120 rows x 2 columns]

# %%
Chem_Name_1= chem_name.drop_duplicates(subset='Chemical Name',inplace=False,keep='first') 
Chem_Name_1 #unique values based on chemical name
# Out:
#                                Canonical_smiles  \
# 0     CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1
# 1         CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1
# 2                                          CC=O
# 3                                    CC(=O)NCCO
# 4               CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
# ...                                         ...
# 3612               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3613               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3614               CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3615              CCCCCCCCCCCC(=O)N(C)CC(=O)O.N
# 3616                  O=C(O)CCN(CC(=O)O)CC(=O)O
#
#                                 Chemical Name
# 0                                ABIETIC ACID
# 1                             ABIETYL ALCOHOL
# 2                                ACETALDEHYDE
# 3                               ACETAMIDE MEA
# 4     ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
# ...                                       ...
# 3612               AMMONIUM LAURETH-7 SULFATE
# ...

# %%
df[['Canonical_smiles','Chemical Name']][df['Canonical_smiles'].duplicated(keep=False)]
# Out:
#                                        Canonical_smiles  \
# 20    Nc1c(N=Nc2ccc([N+](=O)[O-])cc2)c(S(=O)(=O)[O-]...
# 23    CCN(CC)c1ccc(C(=C2C=CC(=[N+](CC)CC)C=C2)c2cc(O...
# 26    CCN(Cc1cccc(S(=O)(=O)[O-])c1)c1ccc(C(=C2C=CC(=...
# 31    O=C1C(c2[nH]c3ccc(S(=O)(=O)[O-])cc3c2O)=Nc2ccc...
# 34    Cc1ccc(Nc2ccc(Nc3ccc(C)cc3S(=O)(=O)[O-])c3c2C(...
# ...                                                 ...
# 3610                       CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3611                       CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3612                       CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3613                       CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3614                       CCCCCCCCCCCCOCCOS(=O)(=O)O.N
#
#                     Chemical Name
# 20                   ACID BLACK 1
# 23                    ACID BLUE 3
# 26                    ACID BLUE 9
# 31                   ACID BLUE 74
# 34                  ACID GREEN 25
# ...                           ...
# 3610     AMMONIUM LAURETH SULFATE
# ...

# %%
Chem_Name_2= chem_name.drop_duplicates(subset='Canonical_smiles',inplace=False,keep='first') 
Chem_Name_2 #unique values based on Canonical_smiles
# Out:
#                                        Canonical_smiles  \
# 0             CC(C)C1=CC2=CCC3C(C)(C(=O)O)CCCC3(C)C2CC1
# 1                 CC(C)C1=CC2=CCC3C(C)(CO)CCCC3(C)C2CC1
# 2                                                  CC=O
# 3                                            CC(=O)NCCO
# 4                       CC(=O)NCCOCCCC[N+](C)(C)C.[Cl-]
# ...                                                 ...
# 3608                Nc1ncnc2c1ncn2C1OC2COP(=O)(O)OC2C1O
# 3609  CCCCCCCCCCCCCCCCOP(=O)([O-])OCCCCCCCCCCCCCCCC....
# 3610                       CCCCCCCCCCCCOCCOS(=O)(=O)O.N
# 3615                      CCCCCCCCCCCC(=O)N(C)CC(=O)O.N
# 3616                          O=C(O)CCN(CC(=O)O)CC(=O)O
#
#                                 Chemical Name
# 0                                ABIETIC ACID
# 1                             ABIETYL ALCOHOL
# 2                                ACETALDEHYDE
# 3                               ACETAMIDE MEA
# 4     ACETAMIDOETHOXYBUTYL TRIMONIUM CHLORIDE
# ...

# %%
with pd.ExcelWriter("Ingred_v2.xlsx") as writer:
  Chem_Name_1['Chemical Name'].to_excel(writer, 
                                        sheet_name='Unique chemical name',
                                        index=False)
  Chem_Name_2['Chemical Name'].to_excel(writer, 
                                        sheet_name='Unique Canonical_smiles',
                                        index=False)

# %%
df[df['Chemical Name'].duplicated(keep=False)]
# Out:
#                                        Canonical_smiles      Chemical Name  \
# 23    CCN(CC)c1ccc(C(=C2C=CC(=[N+](CC)CC)C=C2)c2cc(O...        ACID BLUE 3
# 24    CCN(CC)c1ccc(C(=C2C=CC(=[N+](CC)CC)C=C2)c2cc([...        ACID BLUE 3
# 25    CCN(CC)c1ccc(C(=C2C=CC(=[N+](CC)CC)C=C2)c2cc(O...        ACID BLUE 3
# 26    CCN(Cc1cccc(S(=O)(=O)[O-])c1)c1ccc(C(=C2C=CC(=...        ACID BLUE 9
# 27    CCN(Cc1cccc(S(=O)(=O)[O-])c1)c1ccc(C(=C2C=CC(=...        ACID BLUE 9
# ...                                                 ...                ...
# 3589               On1ccccc1=S.[O-][n+]1ccccc1[S-].[Zn]    ZINC PYRITHIONE
# 3594   C=CCCCCCCCCC(=O)[O-].C=CCCCCCCCCC(=O)[O-].[Zn+2]  ZINC UNDECYLENATE
# 3595           C=CCCCCCCCCC(=O)O.C=CCCCCCCCCC(=O)O.[Zn]  ZINC UNDECYLENATE
# 3596                           C=CCCCCCCCCC(=O)O.[Zn+2]  ZINC UNDECYLENATE
# 3597                               C=CCCCCCCCCC(=O)[O-]  ZINC UNDECYLENATE
#
# ...
